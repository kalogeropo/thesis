# %% [markdown]
# # Number of Cluster Optimization
#
# Selecting the optimal number of clusters is a crucial step in clustering analysis, as it influences the interpretability and quality of the results. Several techniques can be employed to estimate the number of clusters in a graph. Here, we focus on three popular methods used in spectral clustering:
#
# 1. **Eigen-Gap Heuristic**
# 2. **Elbow Method**
# 3. **Silhouette Score**

# %%
from infre.preprocess.collection import Collection

path = "collections/CF/docs"
# load queries, relevant documents, collection
queries, rels = Collection.load_qd("collections/CF")
col = Collection(path).create(first=-1)
# Out:
# Collection Done! 1239 documents were parsed.

# %%
from infre.models.cgsb import ConGSB
from numpy import mean
from time import time

for sim in range (1, 10):
    print(f"Iteration {sim} with Similarity: {sim/10}")
    start_time = time()
    cgsb_model = ConGSB(col, clusters=50, cond={'sim': sim/10},cluster_optimization="eigen_gap")
    pre, rec = cgsb_model.fit_evaluate(queries, rels)
    print(f'CGSB: {mean(pre):.3f}, {mean(rec):.3f}')
    print(cgsb_model.graph.number_of_nodes(), cgsb_model.graph.number_of_edges())
    cgsb_model.save_results(pre, rec)
    print(f"Time: {time()-start_time:.2f}s")
# Out:
# Iteration 1 with Similarity: 0.1
# Cluster optimization is set to eigen_gap
# Cluster optimization is enabled.
# 9620
# 0.009145258608772217 % pruning. 172 edges were pruned out of 1880756.
# Query 1/100: len = 7, frequent = 85
# => Query 1/100, precision = 0.387, recall = 0.515
# Query 2/100: len = 11, frequent = 250
# => Query 2/100, precision = 0.075, recall = 0.571
# Query 3/100: len = 7, frequent = 100
# => Query 3/100, precision = 0.169, recall = 0.512
# Query 4/100: len = 5, frequent = 24
# => Query 4/100, precision = 0.093, recall = 0.556
# Query 5/100: len = 3, frequent = 7
# => Query 5/100, precision = 0.098, recall = 0.504
# Query 6/100: len = 13, frequent = 287
# => Query 6/100, precision = 0.145, recall = 0.521
# Query 7/100: len = 9, frequent = 100
# => Query 7/100, precision = 0.130, recall = 0.518
# Query 8/100: len = 7, frequent = 37
# => Query 8/100, precision = 0.030, recall = 0.523
# Query 9/100: len = 7, frequent = 51
# => Query 9/100, precision = 0.138, recall = 0.550
# Query 10/100: len = 6, frequent = 63
# => Query 10/100, precision = 0.368, recall = 0.520
# Query 11/100: len = 7, frequent = 21
# => Query 11/100, precision = 0.409, recall = 0.523
# Query 12/100: len = 9, frequent = 121
# => Query 12/100, precision = 0.271, recall = 0.571
# Query 13/100: len = 6, frequent = 33
# => Query 13/100, precision = 0.202, recall = 0.521
# Query 14/100: len = 10, frequent = 224
# => Query 14/100, precision = 0.067, recall = 0.509
# Query 15/100: len = 4, frequent = 10
# => Query 15/100, precision = 0.229, recall = 0.505
# Query 16/100: len = 10, frequent = 234
# => Query 16/100, precision = 0.265, recall = 0.503
# Query 17/100: len = 9, frequent = 123
# => Query 17/100, precision = 0.065, recall = 0.509
# Query 18/100: len = 8, frequent = 65
# => Query 18/100, precision = 0.215, recall = 0.524
# Query 19/100: len = 7, frequent = 98
# => Query 19/100, precision = 0.049, recall = 0.523
# Query 20/100: len = 8, frequent = 116
# => Query 20/100, precision = 0.503, recall = 0.511
# Query 21/100: len = 9, frequent = 51
# => Query 21/100, precision = 0.147, recall = 0.520
# Query 22/100: len = 5, frequent = 26
# => Query 22/100, precision = 0.254, recall = 0.507
# Query 23/100: len = 7, frequent = 50
# => Query 23/100, precision = 0.084, recall = 0.514
# Query 24/100: len = 7, frequent = 10
# => Query 24/100, precision = 0.058, recall = 0.516
# Query 25/100: len = 7, frequent = 53
# => Query 25/100, precision = 0.076, recall = 0.510
# Query 26/100: len = 3, frequent = 7
# => Query 26/100, precision = 0.391, recall = 0.515
# Query 27/100: len = 9, frequent = 32
# => Query 27/100, precision = 0.165, recall = 0.545
# Query 28/100: len = 4, frequent = 13
# => Query 28/100, precision = 0.185, recall = 0.510
# Query 29/100: len = 6, frequent = 25
# => Query 29/100, precision = 0.125, recall = 0.511
# Query 30/100: len = 6, frequent = 35
# => Query 30/100, precision = 0.258, recall = 0.529
# Query 31/100: len = 7, frequent = 58
# => Query 31/100, precision = 0.284, recall = 0.509
# Query 32/100: len = 6, frequent = 21
# => Query 32/100, precision = 0.128, recall = 0.517
# Query 33/100: len = 6, frequent = 22
# => Query 33/100, precision = 0.049, recall = 0.509
# Query 34/100: len = 15, frequent = 183
# => Query 34/100, precision = 0.217, recall = 0.513
# Query 35/100: len = 7, frequent = 87
# => Query 35/100, precision = 0.032, recall = 0.536
# Query 36/100: len = 5, frequent = 25
# => Query 36/100, precision = 0.241, recall = 0.556
# Query 37/100: len = 11, frequent = 190
# => Query 37/100, precision = 0.194, recall = 0.505
# Query 38/100: len = 5, frequent = 4
# => Query 38/100, precision = 0.051, recall = 0.509
# Query 39/100: len = 4, frequent = 13
# => Query 39/100, precision = 0.126, recall = 0.503
# Query 40/100: len = 10, frequent = 148
# => Query 40/100, precision = 0.175, recall = 0.503
# Query 41/100: len = 5, frequent = 31
# => Query 41/100, precision = 0.266, recall = 0.533
# Query 42/100: len = 9, frequent = 56
# => Query 42/100, precision = 0.224, recall = 0.511
# Query 43/100: len = 12, frequent = 58
# => Query 43/100, precision = 0.116, recall = 0.505
# Query 44/100: len = 11, frequent = 46
# => Query 44/100, precision = 0.117, recall = 0.504
# Query 45/100: len = 6, frequent = 38
# => Query 45/100, precision = 0.344, recall = 0.525
# Query 46/100: len = 6, frequent = 36
# => Query 46/100, precision = 0.259, recall = 0.528
# Query 47/100: len = 9, frequent = 150
# => Query 47/100, precision = 0.103, recall = 0.508
# Query 48/100: len = 6, frequent = 34
# => Query 48/100, precision = 0.031, recall = 0.517
# Query 49/100: len = 7, frequent = 93
# => Query 49/100, precision = 0.428, recall = 0.514
# Query 50/100: len = 8, frequent = 56
# => Query 50/100, precision = 0.244, recall = 0.520
# Query 51/100: len = 5, frequent = 13
# => Query 51/100, precision = 0.238, recall = 0.502
# Query 52/100: len = 4, frequent = 8
# => Query 52/100, precision = 0.502, recall = 0.750
# Query 53/100: len = 10, frequent = 74
# => Query 53/100, precision = 0.206, recall = 0.522
# Query 54/100: len = 7, frequent = 72
# => Query 54/100, precision = 0.396, recall = 0.508
# Query 55/100: len = 11, frequent = 31
# => Query 55/100, precision = 0.035, recall = 0.521
# Query 56/100: len = 9, frequent = 107
# => Query 56/100, precision = 0.093, recall = 0.516
# Query 57/100: len = 8, frequent = 81
# => Query 57/100, precision = 0.193, recall = 0.510
# Query 58/100: len = 6, frequent = 41
# => Query 58/100, precision = 0.120, recall = 0.505
# Query 59/100: len = 5, frequent = 18
# => Query 59/100, precision = 0.135, recall = 0.503
# Query 60/100: len = 4, frequent = 12
# => Query 60/100, precision = 0.080, recall = 0.515
# Query 61/100: len = 8, frequent = 159
# => Query 61/100, precision = 0.394, recall = 0.507
# Query 62/100: len = 6, frequent = 57
# => Query 62/100, precision = 0.161, recall = 0.503
# Query 63/100: len = 7, frequent = 31
# => Query 63/100, precision = 0.062, recall = 0.513
# Query 64/100: len = 9, frequent = 66
# => Query 64/100, precision = 0.048, recall = 0.510
# Query 65/100: len = 5, frequent = 29
# => Query 65/100, precision = 0.084, recall = 0.505
# Query 66/100: len = 6, frequent = 47
# => Query 66/100, precision = 0.123, recall = 0.508
# Query 67/100: len = 5, frequent = 19
# => Query 67/100, precision = 0.158, recall = 0.536
# Query 68/100: len = 4, frequent = 15
# => Query 68/100, precision = 0.043, recall = 0.511
# Query 69/100: len = 6, frequent = 21
# => Query 69/100, precision = 0.272, recall = 0.533
# Query 70/100: len = 5, frequent = 25
# => Query 70/100, precision = 0.441, recall = 0.529
# Query 71/100: len = 5, frequent = 20
# => Query 71/100, precision = 0.404, recall = 0.583
# Query 72/100: len = 6, frequent = 33
# => Query 72/100, precision = 0.232, recall = 0.538
# Query 73/100: len = 5, frequent = 25
# => Query 73/100, precision = 0.454, recall = 0.528
# Query 74/100: len = 7, frequent = 127
# => Query 74/100, precision = 0.184, recall = 0.571
# Query 75/100: len = 8, frequent = 108
# => Query 75/100, precision = 0.327, recall = 0.524
# Query 76/100: len = 8, frequent = 80
# => Query 76/100, precision = 0.209, recall = 0.529
# Query 77/100: len = 8, frequent = 68
# => Query 77/100, precision = 0.140, recall = 0.506
# Query 78/100: len = 23, frequent = 146
# => Query 78/100, precision = 0.131, recall = 0.506
# Query 79/100: len = 7, frequent = 78
# => Query 79/100, precision = 0.122, recall = 0.512
# Query 80/100: len = 11, frequent = 47
# => Query 80/100, precision = 0.147, recall = 0.515
# Query 81/100: len = 7, frequent = 45
# => Query 81/100, precision = 0.210, recall = 0.518
# Query 82/100: len = 7, frequent = 64
# => Query 82/100, precision = 0.163, recall = 0.508
# Query 83/100: len = 11, frequent = 147
# => Query 83/100, precision = 0.160, recall = 0.516
# Query 84/100: len = 7, frequent = 63
# => Query 84/100, precision = 0.271, recall = 0.531
# Query 85/100: len = 9, frequent = 39
# => Query 85/100, precision = 0.050, recall = 0.516
# Query 86/100: len = 21, frequent = 1554
# => Query 86/100, precision = 0.208, recall = 0.511
# Query 87/100: len = 7, frequent = 67
# => Query 87/100, precision = 0.068, recall = 0.513
# Query 88/100: len = 7, frequent = 83
# => Query 88/100, precision = 0.166, recall = 0.536
# Query 89/100: len = 5, frequent = 17
# => Query 89/100, precision = 0.019, recall = 0.529
# Query 90/100: len = 9, frequent = 275
# => Query 90/100, precision = 0.107, recall = 0.518
# Query 91/100: len = 8, frequent = 141
# => Query 91/100, precision = 0.343, recall = 0.502
# Query 92/100: len = 4, frequent = 15
# => Query 92/100, precision = 0.294, recall = 0.505
# Query 93/100: len = 4, frequent = 12
# => Query 93/100, precision = 0.125, recall = 0.528
# Query 94/100: len = 5, frequent = 11
# => Query 94/100, precision = 0.308, recall = 0.512
# Query 95/100: len = 8, frequent = 61
# => Query 95/100, precision = 0.314, recall = 0.556
# Query 96/100: len = 12, frequent = 104
# => Query 96/100, precision = 0.291, recall = 0.542
# Query 97/100: len = 8, frequent = 113
# => Query 97/100, precision = 0.211, recall = 0.545
# Query 98/100: len = 8, frequent = 59
# => Query 98/100, precision = 0.131, recall = 0.533
# Query 99/100: len = 4, frequent = 9
# => Query 99/100, precision = 0.602, recall = 0.600
# Query 100/100: len = 6, frequent = 21
# => Query 100/100, precision = 0.296, recall = 0.545
# CGSB: 0.198, 0.524
# 9624 1880584
# Time: 28514.83s
# Iteration 2 with Similarity: 0.2
# Cluster optimization is set to eigen_gap
# Cluster optimization is enabled.
# 9620
